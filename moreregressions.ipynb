# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
white = pd.read_csv('winequality-white.csv', delimiter=';')

# %%
red = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
print(white)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
zval2 = red['quality']
plt.figure(figsize=(45, 20))
scatter = plt.scatter(xval2, yval2,
           linewidths=1, alpha=.9,
           edgecolor='k',
           s = 250,
           c=zval2)
plt.xlabel('Fixed Acidity', fontsize=40)
plt.ylabel('Alcohol', fontsize=40)
cbar = plt.colorbar(scatter)
cbar.set_label('Quality', fontsize=40)

plt.tick_params(axis='both', which='major', labelsize=30)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt

white2 = white
red2 = red

X = white2[['free sulfur dioxide', 'total sulfur dioxide', 'residual sugar']]
Y = white2['quality']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state=42)

'''
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test set
Y_pred = model.predict(X_test)

#MSE for linear model
print('Mean Squared Error 1:', metrics.mean_squared_error(y_test, Y_pred))

plt.scatter(range(len(y_test)), y_test, color='brown', label='Actual')


plt.scatter(range(len(Y_pred)), Y_pred, color='black', label='Predicted')

plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Actual vs Predicted Quality')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()
'''
# Initialize the decision tree regressor
regressor = DecisionTreeRegressor()

# Train the regressor on the training data
regressor.fit(X_train, y_train)
scores = cross_val_score(regressor, X, Y, cv=5, scoring='neg_mean_squared_error')

# Make predictions on the testing data
y_pred = regressor.predict(X_test)

# Calculate the mean squared error of the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
mse_mean = -np.mean(scores)
print (mse_mean)
# Out:
# Mean Squared Error: 0.9263888888888888
# 1.3831278214384153

# %%
import matplotlib.pyplot as plt


plt.scatter(range(len(y_test)), y_test, color='brown', label='Actual')


plt.scatter(range(len(y_pred)), y_pred, color='black', label='Predicted')

plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Actual vs Predicted Quality')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(range(len(y_test)), y_test, color='brown', label='Actual')

# Adding labels and title
plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Actual')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(range(len(y_pred)), y_pred, color='black', label='Predicted')

# Adding labels and title
plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Predicted Quality')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
white2 = white
red2 = red

red_X = red2[['free sulfur dioxide', 'total sulfur dioxide', 'residual sugar']]
red_Y = red2['quality']

# Split the dataset into training and testing sets
redX_train, redX_test, red_y_train, red_y_test = train_test_split(red_X, red_Y, test_size=0.2, random_state=42)

# Initialize the decision tree regressor
regressor = DecisionTreeRegressor()

# Train the regressor on the training data
regressor.fit(redX_train, red_y_train)
scores = cross_val_score(regressor, red_X, red_Y, cv=5, scoring='neg_mean_squared_error')

# Make predictions on the testing data
red_y_pred = regressor.predict(redX_test)

# Calculate the mean squared error of the model
mse = mean_squared_error(red_y_test, red_y_pred)
print("Mean Squared Error:", mse)
mse_mean = -np.mean(scores)
print (mse_mean)
# Out:
# Mean Squared Error: 1.0186631944444442
# 1.3865245667885753

# %%
plt.scatter(range(len(red_y_test)), red_y_test, color='red', label='Actual')

# Plotting the predicted values
plt.scatter(range(len(red_y_pred)), red_y_pred, color='green', label='Predicted')

# Adding labels and title
plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Actual vs Predicted Quality')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
plt.scatter(range(len(red_y_test)), red_y_test, color='red', label='Actual')


# Adding labels and title
plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Actual')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
plt.scatter(range(len(red_y_pred)), red_y_pred, color='green', label='Predicted')

# Adding labels and title
plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Predicted')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()

# %%
red_X_trainLin, red_X_testLin, red_y_trainLin, red_y_testLin = train_test_split(red_X, red_Y, test_size=0.2,random_state=42)

model = LinearRegression()

# Fit the model to the training data
model.fit(red_X_trainLin, red_y_trainLin)

# Make predictions on the test set
red_Y_predLin = model.predict(red_X_testLin)

#MSE for linear model
print('Mean Squared Error:', metrics.mean_squared_error(red_y_testLin, red_Y_predLin))

plt.scatter(range(len(red_y_test)), red_y_test, color='red', label='Actual')

# Plotting the predicted values
plt.scatter(range(len(red_Y_predLin)), red_y_pred, color='green', label='Predicted')

plt.xlabel('Independent Variables')
plt.ylabel('Quality')
plt.title('Actual vs Predicted Quality')

# Adding a legend
plt.legend()

# Displaying the plot
plt.show()
# Out:
# Mean Squared Error: 0.6438293735324837
